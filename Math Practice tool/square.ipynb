# %%
import time 

import numpy as np

while True:
    x = np.random.randint(16,30,1)
    time.sleep( 1.5 )
    print ( x )
    time.sleep( 0.5 )
    print( x*x )
# Out:
# [28]
# [784]
# [26]
# [676]
# [28]
# [784]
# [27]
# [729]
# [25]
# [625]
# [28]
# [784]
# [19]
# [361]
# [18]
# [324]
# [27]
# [729]
# [25]
# [625]
# [18]
# [324]
# [18]
# [324]
# [22]
# [484]
# [26]
# [676]
# [27]
# [729]
# [20]
# [400]
# [20]
# [400]
# [26]
# [676]
# [23]
# [529]
# [20]
# [400]
# [17]
# [289]
# [18]
# [324]
# [24]
# [576]
# [19]
# [361]
# [25]
# [625]
# [20]
# [400]
# [18]
# [324]
# [22]
# [484]
# [27]
# [729]
# [23]
# [529]
# [19]
# [361]
# [23]
# [529]
# [19]
# [361]
# [22]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 9
#       7 time.sleep( 1.5 )
#       8 print ( x )
# ----> 9 time.sleep( 0.5 )
#      10 print( x*x )
#
# KeyboardInterrupt:
