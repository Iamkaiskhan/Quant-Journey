# %% [markdown]
# # To know the location of the directory

# %%
import os

current_directory=os.getcwd()

print(current_directory)
# Out:
# c:\Users\HP\Documents\GitHub\Quant-Journey\month-01-python

# %% [markdown]
# # To change the location of the directory

# %%
import os

current_directory=os.getcwd()

print(current_directory)


os.chdir(r"c:\Users\HP\Documents\GitHub\Quant-Journey\month-01-python\game")
print(os.getcwd())
# Out:
# c:\Users\HP\Documents\GitHub\Quant-Journey\month-01-python\game
# c:\Users\HP\Documents\GitHub\Quant-Journey\month-01-python\game
