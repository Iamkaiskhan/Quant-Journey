# %% [markdown]
# # Concept about files

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If we dont give the mode in the file ,it will pre assume it as read mode 'r'
