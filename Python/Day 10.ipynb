# %%
#lets learn about nonlocal variable

# nonlocal variable is a variable inside a nested function 
#  the nonlocal keyword is used within nested functions to indicate that a variable is not local to the inner function,
#but rather belongs to an enclosing function’s scope.

def outer():
    message='Local'
    
    def inner():
        nonlocal message
        message='Nonlocal'

        print('Inner:',message)
    inner()
    print('Outer:',message)

outer()
# Out:
# Inner: Nonlocal
# Outer: Nonlocal

# %%
# lets learn about global variable

# example 1 

c=1
def test1():
    print(c)

test1()     # output : 1


# example 2
c=2
def test2():
    c=c+1
    print(c)

#test2()  #it will show error because c is global variable and it cannot be accesed

# example 3
c=5
def test3():
    global c
    c+=2
    print(c)

test3()      # it will show the output as required
# Out:
# 1
# 7

# %%
# lets learn about recursion

def factorial(num):

    if num== 1:
        return 1

    elif num==0:
        return 1
        
    else:
        return(num * factorial(num-1))


num=int(input('Enter the number:'))
factorial=factorial(num)
print(factorial)
# Out:
# Enter the number: 0
# 1

# %%
# to calculate the sum of natural number

def sum_natural(n):

    if n==1:
        return 1

    else:
        return sum_natural(n-1)+n

n=int(input('Enter the nth number:'))
sum=sum_natural(n)
print(f'the sum of first n natural number is {sum}')
# Out:
# Enter the nth number: 5
# the sum of first n natural number is 15

# %%
# to display fibonacci sequence
def fibonnaci(n):
    if n==1:
        list1=[1]
        return list1

    elif n==2:
        list2=[1,1]
        return list2

    elif n>=3:
        

list3=[1,1]
fibonnaci(2)
# Out:
# [1, 1]
