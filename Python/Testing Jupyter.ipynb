# %%
name = 'Kais'

# %%
print(name)

# %%
# !pip list

# %%
# %ls magic
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 66A3-C284
#
#  Directory of C:\Users\HP\Documents\GitHub\Quant-Journey\month-01-python
# File Not Found

# %%
# %ls

# %%
# %pwd #it prints the current working directory

# %%
# %ls #it lists the files in the directory

# %%
# %%HTML
# ## Heading <br>
# Now this will treat this cell as HTML
# Out:
# ## Heading <br>
# Now this will treat this cell as HTML

# %%
 #it will tell me the average time taken to execute the code
a=1
if a==1 :
    print ("kais")
