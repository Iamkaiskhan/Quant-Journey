# %%
# we will solve example to print fibonacci using recursion

def fibonacci(n):
    if n<=1:
        return n

    else:
        return fibonacci(n-1)+fibonacci(n-2)



while True:
    user_input=input('Enter the number of terms:')

    try:
        num=int(user_input)
    except:
        print('That\'s not a valid input')
        continue

    if num<=0:
        print('That\'s not a valid input')
        continue

    break

    
series=[]

print('The fibonacci series is:')
for i in range(num):
    series.append(fibonacci(i))

print(series)
# Out:
# Enter the number of terms: 5
# The fibonacci series is:
# [0, 1, 1, 2, 3]

# %%
# now we learn about modules 
# method 1
import math
print(math.pi)

# method 2
import math as m      # it will rename math as we wsant,in this case its 'm'
print(m.cos(m.pi))

# method 3
from math import pi,sin,cos    # it will directly import pi

print(pi,sin(pi/2),cos(pi))

pi=1        # be aware ,here we cannot use the same variable for other uses
print(pi)


# method 4 
from math import *   # this will include all the variables inside math module

print(pi,sqrt(16))
# Out:
# 3.141592653589793
# -1.0
# 3.141592653589793 1.0 -1.0
# 1
# 3.141592653589793 4.0
