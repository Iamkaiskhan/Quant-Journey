# %% [markdown]
# ![image.png](attachment:028d11cf-48dc-45db-918a-8b79e9195742.png)
#
# <br>
#
# ![image.png](attachment:ceadf1fd-1949-455b-bb18-1a3e995f8056.png)

# %% [markdown]
# ![image.png](attachment:7225849c-1dce-4372-a70e-4d28b248073f.png)
#
# <br>
#
# ![image.png](attachment:8a057cd6-be58-4e5e-8c58-96ef8f9fd1a1.png)

# %% [markdown]
# ![image.png](attachment:5fb6f08a-6b67-4ba2-bb68-506fe60ccac6.png)
