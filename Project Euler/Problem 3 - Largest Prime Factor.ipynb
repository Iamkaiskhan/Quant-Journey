# %%
# MY APPROACH WHICH WONT WORK BECAUSE IT WILL ITERATE 600 BILLION TIMES ATLEAST


# making function will return the largest prime factor of a number
def prime_factor(x):
    list = []
    status = True
    i = 1
    while status :
        if ( x % i == 0 ):
            list.append( i )
            
        i+=1
        if i==x+1:
            status = False

    print( list )
    list.remove(1)
    print()
    print(list)
    print()

    prime = []
    for z in list:
        is_prime = True
        
        for i in range(2,z):
            
            if z % i == 0 :
                is_prime = False
                break

        if is_prime :
            prime.append( z )
                
                
                
            
           

    print( prime )
prime_factor( int(input( 'Enter the number: ' ) ) )
# Out:
# Enter the number:  29
# [1, 29]
#
# [29]
#
# [29]

# %%
# Efficient method 

def prime(x):
    d = 2
    while d * d <= x :
        if x % d == 0:
            x = x // d

        else :
            d+=1

    return x

prime( int(input("Enter the number::")))
# Out:
# Enter the number:: 600851475143
# 6857
