# %%
# making function will return the largest prime factor of a number
def prime_factor(x):
    list = []
    status = True
    i = 1
    while status :
        if ( x % i == 0 ):
            list.append( i )
            
        i+=1
        if i==x+1:
            status = False

    #print( list )
    list.remove(1)
    print()
    #print(list)
    print()
    a = 1
    
    list1 = []
    for z in list:
        while True :
            if z % a == 0 :
                a=2
                break

            a+=1
            
            if z == a:
                list1.append(z)
                
                
            
           

    print( list1 )
prime_factor( int(input( 'Enter the number: ' ) ) )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 38
#      31                 list1.append(z)
#      37     print( list1 )
# ---> 38 prime_factor( int(input( 'Enter the number: ' ) ) )
#
# Cell In[3], line 7, in prime_factor(x)
#       5 i = 1
#       6 while status :
# ----> 7     if ( x % i == 0 ):
#       8         list.append( i )
#      10     i+=1
#
# KeyboardInterrupt:
