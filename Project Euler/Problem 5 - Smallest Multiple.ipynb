# %%
import numpy as np

a = 100
add = 0
while True :
    str1 = str( a )
    number = int( str1[-1] ) + int( str1[-2] ) * 10 + int( str1[-3]) * 100
    for i in str1 :
        add = add + int ( i )

        
    if add % 9 == 0 and number % 8 == 0 and a % 7 == 0 :
        print(a)
        break

    else:
        a+=20
        add = 0

print ( a * 13 * 11 * 17 * 19 * 2 )
# Out:
# 2520
# 232792560

# %%
# the actual way

from math import log
import numpy as np

k = int( input( 'Enter the number' ) ) 
prime_numbers = np.array( [] )

while True :

    for i in range ( 2 , k+1 ) :
        is_prime = True
        for j in range( 2 , i ) :
            if i % j == 0 :
                is_prime = False
                break

        if is_prime :
            prime_number = np.append( prime_numbers , i )

    break

print( prime_numbers )
# Out:
# Enter the number 5
# []
