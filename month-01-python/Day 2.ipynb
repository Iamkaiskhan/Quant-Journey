# %%
print("Hello World")
# Out:
# Hello World

# %%
print('Hello World')
# Out:
# Hello World

# %%
# We learn how to use comment
# declare a variable
name = 'kais'
# print name 
print(name)  # kais
# Out:
# kais

# %%
''' We can use this to comment multi line
my name is kais '''
print (name)
# Out:
# kais

# %%
# make a program to take input
name = input("Enter your name: ")
age = int(input("Enter age: "))
print ("Your name is",name, "and ur age is",age)
# Out:
# Enter your name:  kais
# Enter age:  20
# Your name is kais and ur age is 20

# %%
# assign value to site_name variable 
site_name = 'tradingview'
print(site_name)

#now changing the value of variable
site_name = 'pipfarm.com'
print(site_name)
# Out:
# tradingview
# pipfarm.com

# %%
# Method to assign values to different variables at a time 
a ,b , c = 5, 3.2 , "Kais Khan"
print(a,b,c)
# Out:
# 5 3.2 Kais Khan

# %%
name = 'kais'
# here "name" is variable and 'kais' is termed as literal 
number1 = 3.2
number2 = -8
number3 = 3+6j
print(number3)
# Out:
# (3+6j)

# %%
# lets discuss about some more literals 
is_pass = True
print(is_pass)

is_fail = False

value= None
print(value)
# Out:
# True
# None

# %%
# We will discuss about some collection literals 
# list literal
fruits = ['apple','mango','orange']
print(fruits)

#tuple literal
numbers = (1,2,3)
print(numbers)

# dictionary literal
alphabets = { 'a' : 'apple', 'b' : 'ball', 'c' : 'cat'}
print(alphabets)

# set literal 
vowels = {'a','e','i','o','u'}
print(vowels)
# Out:
# ['apple', 'mango', 'orange']
# (1, 2, 3)
# {'a': 'apple', 'b': 'ball', 'c': 'cat'}
# {'o', 'u', 'i', 'a', 'e'}

# %%
city= 'Mumbai'
print(city)
print('city:',city)
# Out:
# Mumbai
# city: Mumbai

# %%
# lets learn about Type conversion
# 1. implicit type conversion which is automatically done by the python
# 2. explicit tpye conversion whhich means we need to do manually conversion of data type
# Explicit type conversion is also known as Type casting
# e.g for implicit case
integer_number = 123
float_number = 3.261

new_number = integer_number + float_number
print('value',new_number)
print('Data Type',type(new_number))

# e.g. for explicit case
num_string = '12'
num_integer = 23
print('Data type of num_string before Type casting:',type(num_string))
num_string = int(num_string)
print('Data type of num_string after Type casting:',type(num_string))

num_sum = num_string + num_integer
print('Sum:',num_sum)
print('Data types of num_sum:',type(num_sum))
# Out:
# value 126.261
# Data Type <class 'float'>
# Data type of num_string before Type casting: <class 'str'>
# Data type of num_string after Type casting: <class 'int'>
# Sum: 35
# Data types of num_sum: <class 'int'>

# %%
# Syntax of print()

# the actual syntax of the print function accepts 5 parameters

# print(object= separator= end= file= flush=)
# Here,

# object - value(s) to be printed
# sep (optional) - allows us to separate multiple objects inside print().
# end (optional) - allows us to add add specific values like new line "\n", tab "\t"
# file (optional) - where the values are printed. It's default value is sys.stdout (screen)
# flush (optional) - boolean specifying if the output is flushed or buffered. Default: False

print('Good Morning!')
print('It is rainy today')

# In the above example, the print() statement only includes the object to be printed. 
# Here, the value for end is not used. Hence, it takes the default value '\n'.
# Out:
# Good Morning!
# It is rainy today

# %%
# print with end whitespace
print('Good Morning!', end= ' ')

print('It is rainy today')

# We can also join two strings together inside the print() statement. For example,
print( 'Kais '+ 'Khan')
# Out:
# Good Morning! It is rainy today
# Kais Khan

# %%
# Sometimes we would like to format our output to make it look attractive. 
# This can be done by using the str.format() method. For example,
x= 5
y= 10
print('The values of x {} and y is {} '.format(x,y))
# Out:
# The values of x 5 and y is 10

# %%
# lets learn about input 
# the input is in string always
num = input('Enter your age:')
print('The data type is:',type(num))

age= int(input('Enter your age:'))
print('The data type is:',type(age))
# Out:
# Enter your age: 3030
# The data type is: <class 'str'>
# Enter your age: 30
# The data type is: <class 'int'>

# %%
# Lets learn about operators
# Operator	Operation	Example
# +	Addition	5 + 2 = 7
# -	Subtraction	4 - 2 = 2
# *	Multiplication	2 * 3 = 6
# /	Division	4 / 2 = 2
# //	Floor Division	10 // 3 = 3
# %	Modulo	5 % 2 = 1
# **	Power	4 ** 2 = 16 

power = 2**4
floor_division = 50//6
modulo = 90% 7
print(power)
print(floor_division)
print(modulo)
# Out:
# 16
# 8
# 6

# %%
# Operator	Name	Example
# =	Assignment Operator	a = 7
# +=	Addition Assignment	a += 1 # a = a + 1
# -=	Subtraction Assignment	a -= 3 # a = a - 3
# *=	Multiplication Assignment	a *= 4 # a = a * 4
# /=	Division Assignment	a /= 3 # a = a / 3
# %=	Remainder Assignment	a %= 10 # a = a % 10
# **=	Exponent Assignment	a **= 10 # a = a ** 10

a=5
print(a)
a +=5
print(a)
a -=3
print(a)
a *=2
print(a)
a /= 3
print(a)
a=int(a)
a %=4
print(a)
a **= 3
print(a)
# Out:
# 5
# 10
# 7
# 14
# 4.666666666666667
# 0
# 0

# %%
# Comparison operators 
a=4
b=7
print(a>b)
print(a==b)
print(a<b)
print(a!=b)
print(a>=b)
print(a<=b)
# Out:
# False
# False
# True
# True
# False
# True

# %%
# Lets learn about logical operators
a= 3
b = 7
print( a>1 and b<4)
print( a>9 or b<10)
print ( not a>1)

# logical AND
print(True and True)     # True
print(True and False)    # False

# logical OR
print(True or False)     # True

# logical NOT
print(not True)          # False
# Out:
# False
# True
# False
# True
# False
# True
# False
